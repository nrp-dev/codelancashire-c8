# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as npn

# %%
sleep_df = pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')

sleep_df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
sleep_df.describe() #not really useful!
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
hist_plot = sleep_df.hist('Age')

hist_plot
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %%
sleep_df['Occupation'].value_counts()
# Out:
# Occupation
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Software Engineer        4
# Scientist                4
# Sales Representative     2
# Manager                  1
# Name: count, dtype: int64

# %%
grouped_occ = sleep_df.groupby(['Occupation','Gender'])

# %%
doc_df = sleep_df[sleep_df['Occupation'] == 'Doctor']

male_doc = doc_df[doc_df['Gender'] == 'Male']

doc_df.groupby('Gender')['Age'].mean()
# Out:
# Gender
# Female    56.0
# Male      32.0
# Name: Age, dtype: float64

# %%
female_doc = doc_df[doc_df['Gender'] == 'Female']

female_doc

female_doc.describe()
# Out:
#         Person ID        Age  Sleep Duration  Quality of Sleep  \
# count   75.000000  75.000000       75.000000         75.000000
# mean   297.093333  51.906667        7.093333          7.413333
# std     87.762606   7.683210        0.994082          1.551750
# min     17.000000  29.000000        5.900000          5.000000
# 25%    281.500000  50.000000        6.100000          6.000000
# 50%    304.000000  51.000000        7.100000          7.000000
# 75%    355.500000  58.000000        8.100000          9.000000
# max    374.000000  59.000000        8.200000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count                75.000000     75.000000   75.000000     75.000000
# mean                 78.893333      5.480000   71.813333   8109.333333
# std                  13.694123      2.395717    3.885849   1897.378941
# min                  35.000000      3.000000   65.000000   4000.000000
# ...

# %%
#Select Medical Pros
med_df = sleep_df[(sleep_df.Occupation == 'Doctor') | (sleep_df.Occupation == 'Nurse')  ]
med_df
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 1            2    Male   28     Doctor             6.2                 6
# 2            3    Male   28     Doctor             6.2                 6
# 7            8    Male   29     Doctor             7.8                 7
# 8            9    Male   29     Doctor             7.8                 7
# 9           10    Male   29     Doctor             7.8                 7
# ..         ...     ...  ...        ...             ...               ...
# 369        370  Female   59      Nurse             8.1                 9
# 370        371  Female   59      Nurse             8.0                 9
# 371        372  Female   59      Nurse             8.1                 9
# 372        373  Female   59      Nurse             8.1                 9
# 373        374  Female   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# ...

# %%
grouped_med = med_df.groupby(['Occupation', 'Gender'])

grouped_med['Sleep Duration'].mean()
# Out:
# Occupation  Gender
# Doctor      Female    8.200000
#             Male      6.934783
# Nurse       Female    7.063014
# Name: Sleep Duration, dtype: float64

# %%
sleep_df.plot.scatter(x = 'Physical Activity Level', y = 'Quality of Sleep')
# Out:
# <Axes: xlabel='Physical Activity Level', ylabel='Quality of Sleep'>

# %%
sleep_df.plot.scatter(x = 'Sleep Duration', y = 'Quality of Sleep')
# Out:
# <Axes: xlabel='Sleep Duration', ylabel='Quality of Sleep'>
